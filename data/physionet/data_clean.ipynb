# %%
import numpy as np
import wfdb
import glob
import os



#USAGE:
data = np.load("./mitdrivedb_data.npy")
labels = np.load("./mitdrivedb_labels.npy")

# %%
data = np.load("./phy_data.npy")
labels = np.load("./phy_labels.npy")

# %%
print(labels)
# Out:
# ['ECG' 'EMG' 'foot GSR' 'hand GSR' 'HR' 'RESP']

# %%
print(data.shape)
# Out:
# (23655, 6)

# %%
data = np.loadtxt( 'drive05.dat' )
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-25-89cace34a8fc> in <module>
# ----> 1 data = np.loadtxt( 'drive05.dat' )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1110         try:
#    1111             while not first_vals:
# -> 1112                 first_line = next(fh)
#    1113                 first_vals = split_line(first_line)
#    1114         except StopIteration:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcf in position 0: invalid continuation byte

# %%
# Filters the data and updates the matrix as needed
def filterData(signals, labels, filterLabels):
  # Remove the marker datapoint
    remIdx = labels.index("marker") if "marker" in labels else -1
    if (remIdx != -1):
        del labels[remIdx]
        signals = np.delete(signals, remIdx, 1)
        # Filter out only data that has these labels
    include = False
    if labels == filterLabels:
        include = True
    return include, signals


# Preprocesses all files in the database
def preprocess():
    filterLabels = ['ECG', 'EMG', 'foot GSR', 'hand GSR', 'HR', 'RESP']
    labels = np.array(filterLabels)
    D = len(filterLabels)
    data = np.zeros((0, D))
    os.chdir(".")
    for file in glob.glob("*.dat"):
        signals, fields = wfdb.rdsamp(file)
        include, signals = filterData(signals, fields["sig_name"], filterLabels)
    if include:
        data = np.concatenate((data, signals))
        np.save("./phy_data.npy", data)
        np.save("./phy_labels.npy", labels)
    return



# Driver code
def main():
    preprocess()



if __name__ == '__main__':
    main()
